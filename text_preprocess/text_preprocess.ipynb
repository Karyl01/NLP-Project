# %%
# !python clean_and_extract.py

# %% [markdown]
# medical_clean_corpus.txt

# %%
# !python preprocess.py

# %% [markdown]
# 2——cleaned_corpus.txt

# %%
# !python extract_words.py

# %% [markdown]
# extracted_medical_new_words_pure_vocab.txt，手洗得到 flashed_medical_words.txt,对应在extracted_medical_new_words_pure_vocab.txt的前3000个词
