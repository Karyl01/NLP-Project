# %%
# !python merge_vocab.py
# Out:
# 正在加载原始 Qwen2.5 Tokenizer 与模型...
# 正在读取你清洗好的医学词汇表: output.txt...
# 准备添加的新词数量: 5663 个。
# Tokenizer 扩充成功！实际新增了 4629 个专属医学 Token。
# 当前原始词表大小: 151663 -> 扩充后目标词表大小: 156292
# 模型 Embedding 层与 LM Head 维度重缩放完成（新增维度已自动随机初始化）。
# 正在将融合后的新模型资产保存至: ../models/qwen2.5-1.5B-MedVocab...
# 专属医学底模资产准备就绪！
# ...
# Loading weights: 100%|██████████| 338/338 [00:00<00:00, 4225.09it/s]
# [transformers] The new embeddings will be initialized from a multivariate normal distribution that has old embeddings' mean and covariance. As described in this article: https://nlp.stanford.edu/~johnhew/vocab-expansion.html. To disable this, use `mean_resizing=False`
#
# ...
# Writing model shards: 100%|██████████| 1/1 [00:28<00:00, 28.71s/it]

# %%
# !python ablation_compression.py
# Out:
# 正在加载原始与新 Tokenizer...
# 正在扫描文件行数: ../medical_datasets/medical/pretrain/test_encyclopedia.json...
# 文件总计包含 500 行数据。
# 警告：文件总行数不足 1000，将对全量数据进行评测。
# 开始流式提取并计算这 500 条样本文本的 Token 压缩率...
#
# ========================================词表扩充消融分析报告 ========================================
# 评测样本量                    : 500 条医学文本
# 原始 Qwen2.5 平均 Token 长度  : 374.80
# 扩充医学词表后 平均 Token 长度: 354.20
# 文本序列平均压缩率 (序列缩短)  : 5.50%
# 结论说明：在微调训练阶段，单批次（Batch）的平均显存开销将降低约 5.5%，
#              同时模型的上下文窗口（Context Window）利用率和推理速度将获得显著提升！
# ...
# 文本抽样比对中: 100%|██████████| 500/500 [00:00<00:00, 792.98it/s]
